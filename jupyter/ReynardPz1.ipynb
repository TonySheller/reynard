# %% [markdown]
# # Reynard
#
# ### Anthony Sheller <br> EN.605.745<br>Reasoning Under Uncertainty
#
# ### Puzzle 1

# %%
# This lets me import the Python modules from the directory below this one
import sys
sys.path.insert(0, '../../reynard')


from pylab import *
import matplotlib.pyplot as plt
import os
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
from puzzle import Puzzle
from agent import Agent
from reynard_constants import *
import operator
from time import time,sleep
from datetime import timedelta

# %%
class PZ1_Eval:

    def __init__(self,puzzle):

        agent = Agent(puzzle)
        self.agent = agent
        agent.VERBOSE = False
        agent.startPuzzle()
        print("Puzzle 1")
        if agent.puzzle.wordsOfLength(1):
            if not agent.puzzle.bothAandI():
                for ltr in ['A','I']:
                    agent.assignAorI(agent.root, ltr)
            else:
                agent.assignAorI(agent.root, ['A','I'])
            agent.twoLtWdsBeginWithAorI()  

        startTime = time()
        if agent.puzzle.wordsOfLength(2):
            startTime = time()
            for child in agent.root.children:
                agent.processTwoLetterWords(child,0,5)
            endTime = time()
            elapsed = endTime - startTime
            elapsedTwo = str(timedelta(seconds=elapsed))
            print("Puzzle 1 -- Execution time for two letter words is {}".format(elapsedTwo))  
            maxVal = max(self.getHighestUtility(agent.root,[]))
            print("Puzzle 1 -- Maximum Utility is {}".format(round(maxVal,3)))
            print("Puzzle 1  -- Node Count at {}".format(agent.node_count))
            self.evaluateChildrenForKey(agent.root, False)
            self.evaluateChildrenForKeyThree(agent.root,returnValue =False)
            
        startTime = time()
        if agent.puzzle.wordsOfLength(3):
            startTime = time()
            for child in agent.root.children:
                agent.processThreeLetterWords(child,0,5)
            endTime = time()
            elapsed = endTime - startTime
            elapsedTwo = str(timedelta(seconds=elapsed))
            print("Puzzle 1 -- Execution time for three letter words is {}".format(elapsedTwo))  
            maxVal = max(self.getHighestUtility(agent.root,[]))
            print("Puzzle 1 -- Maximum Utility is {}".format(round(maxVal,3)))
            print("Puzzle 1  -- Node Count at {}".format(agent.node_count))
            self.evaluateChildrenForKey(agent.root, False)
            self.evaluateChildrenForKeyThree(agent.root,returnValue =False)
            

    def evaluateChildrenForKey(self,node,returnValue):
        '''
        Helper function for the tests 
        '''
        if len(node.children) > 0: 
            for child in node.children:
                self.evaluateChildrenForKey(child,returnValue)
        else:
           returnValue = self.checkkeyTwoLetters(node)
        return returnValue

    def evaluateChildrenForKeyThree(self,node,returnValue):
        '''
        Helper function for the tests 
        '''
        if len(node.children) > 0: 
            for child in node.children:
                self.evaluateChildrenForKeyThree(child,returnValue)
        else:
           returnValue = self.checkkeyMoreLetters(node)
        return returnValue       

    def checkkeyTwoLetters(self,node):
        '''
        Helper function for the tests
        '''
        returnVal = False
        if all([k in list(node.letter.keys()) for k in list('XCKG') ]):
                if node.letter['X'] == 'A':
                    if node.letter['C'] == 'I':
                        if node.letter['K'] == 'T':
                            if node.letter['G'] == 'O':
                                print("\n\tKey {} :: \n\tUtility of {} present in the puzzle\n".format(node.letter,round(node.utility,3)))
                                self.agent.showProgressPuzzle(node)
        # Leaving the system stack and not finding what we want
        return returnVal

    def checkkeyMoreLetters(self,node):
        '''
        Helper function for the tests
        '''
        returnVal = False
        if all([k in list(node.letter.keys()) for k in list('XCKGQM') ]):
                if node.letter['X'] == 'A':
                    if node.letter['C'] == 'I':
                        if node.letter['K'] == 'T':
                            if node.letter['G'] == 'O':
                                if node.letter['Q'] == 'M':
                                    if node.letter['M'] == 'E':
                                        print("\n\tBigger Key {} :: \n\tUtility of {}  present in the puzzle\n".format(node.letter,round(node.utility,3)))
                                        self.agent.showProgressPuzzle(node)
        # Leaving the system stack and not finding what we were
        return returnVal

    def getHighestUtility(self,node,maxVal=[]):
        '''
        What is the highest utility in the tree
        '''
        if len(node.children) > 0: 
            for child in node.children:
                self.getHighestUtility(child,maxVal)    
        else:
            maxVal.append(node.utility)
        return maxVal

# %%
PUZZLE = Puzzle('../data/pz1.txt')
pz1_eval = PZ1_Eval(PUZZLE)
# Out:
# Puzzle 1
#
#
# ****0****
#
#
#  TIME ELAPSED IS 0:00:00.140501
#
#
# ****1****
#
#
#  TIME ELAPSED IS 0:00:03.176957
#
#
# ****2****
#
#
#  TIME ELAPSED IS 0:00:04.549420
#
#
# ****3****
#
#
#  TIME ELAPSED IS 0:00:04.319429
#
#
# ****0****
#
#
#  TIME ELAPSED IS 0:00:00.360298
#
#
# ****1****
#
#
#  TIME ELAPSED IS 0:00:01.055769
#
#
# ****2****
#
#
#  TIME ELAPSED IS 0:00:01.004085
#
#
# ****3****
#
#
#  TIME ELAPSED IS 0:00:01.009839
# Puzzle 1 -- Execution time for two letter words is 0:00:15.617005
# Puzzle 1 -- Maximum Utility is 0.186
# Puzzle 1  -- Node Count at 40
#
# 	Key {'X': 'A', 'C': 'I', 'K': 'T', 'G': 'O', 'H': 'N'} ::
# 	Utility of 0.186 present in the puzzle
#
# IT O_____ TO __ _O_ T_AT T_I_ _A_
# CK GEEZOT KG QM IGP KWXK KWCT PXT
# T__ __A_ _O_ ON _A__I__:  TO __T__
# KWM OMXA RGB GH NXIECIY:  KG MIKMO
# A _O___ ___I__ T__ O__ _O_ NI__
# X PGOAN ZIACJM KWM GIM BGZ HCIN
# _O_____N ________ _IT_, A__ _O__
# BGZOTMAH LZONMIMN PCKW, XIN QGSM
# _O__ _O__ TO_A__ _OT_I__ __T A
# BGZO LGNB KGPXON IGKWCIY LZK X
# __A___ T_AT TI__ _I__T __O_
# DOXBMO KWXK KCQM QCYWK TAGP
# _O__.
# NGPI.
#
# 	Key {'X': 'A', 'C': 'I', 'K': 'T', 'G': 'O', 'H': 'F'} ::
# 	Utility of 0.186 present in the puzzle
#
# IT O_____ TO __ _O_ T_AT T_I_ _A_
# CK GEEZOT KG QM IGP KWXK KWCT PXT
# T__ __A_ _O_ OF _A__I__:  TO __T__
# KWM OMXA RGB GH NXIECIY:  KG MIKMO
# A _O___ ___I__ T__ O__ _O_ FI__
# X PGOAN ZIACJM KWM GIM BGZ HCIN
# _O_____F ________ _IT_, A__ _O__
# BGZOTMAH LZONMIMN PCKW, XIN QGSM
# _O__ _O__ TO_A__ _OT_I__ __T A
# BGZO LGNB KGPXON IGKWCIY LZK X
# __A___ T_AT TI__ _I__T __O_
# DOXBMO KWXK KCQM QCYWK TAGP
# _O__.
# NGPI.
# Puzzle 1 -- Execution time for three letter words is 0:09:44.032387
# Puzzle 1 -- Maximum Utility is 0.578
# Puzzle 1  -- Node Count at 10
#
# 	Key {'X': 'A', 'C': 'I', 'K': 'T', 'G': 'O', 'H': 'N', 'W': 'H', 'M': 'E', 'L': 'B', 'Z': 'U'} ::
# 	Utility of 0.474 present in the puzzle
#
# IT O__U__ TO _E _O_ THAT THI_ _A_
# CK GEEZOT KG QM IGP KWXK KWCT PXT
# THE _EA_ _O_ ON _A__I__:  TO E_TE_
# KWM OMXA RGB GH NXIECIY:  KG MIKMO
# A _O___ U__I_E THE O_E _OU NI__
# X PGOAN ZIACJM KWM GIM BGZ HCIN
# _OU__E_N BU__E_E_ _ITH, A__ _O_E
# BGZOTMAH LZONMIMN PCKW, XIN QGSM
# _OU_ BO__ TO_A__ _OTHI__ BUT A
# BGZO LGNB KGPXON IGKWCIY LZK X
# __A_E_ THAT TI_E _I_HT __O_
# DOXBMO KWXK KCQM QCYWK TAGP
# _O__.
# NGPI.
#
# 	Key {'X': 'A', 'C': 'I', 'K': 'T', 'G': 'O', 'H': 'N', 'I': 'R', 'N': 'E', 'L': 'B', 'Z': 'U'} ::
# 	Utility of 0.298 present in the puzzle
#
# IT O__U__ TO __ RO_ T_AT T_I_ _A_
# CK GEEZOT KG QM IGP KWXK KWCT PXT
# T__ __A_ _O_ ON EAR_IR_:  TO _RT__
# KWM OMXA RGB GH NXIECIY:  KG MIKMO
# A _O__E UR_I__ T__ OR_ _OU NIRE
# X PGOAN ZIACJM KWM GIM BGZ HCIN
# _OU____N BU_E_R_E _IT_, ARE _O__
# BGZOTMAH LZONMIMN PCKW, XIN QGSM
# _OU_ BOE_ TO_A_E ROT_IR_ BUT A
# BGZO LGNB KGPXON IGKWCIY LZK X
# __A___ T_AT TI__ _I__T __O_
# DOXBMO KWXK KCQM QCYWK TAGP
# EO_R.
# NGPI.
#
# 	Key {'X': 'A', 'C': 'I', 'K': 'T', 'G': 'O', 'H': 'N', 'L': 'B', 'Z': 'U'} ::
# 	Utility of 0.244 present in the puzzle
#
# IT O__U__ TO __ _O_ T_AT T_I_ _A_
# CK GEEZOT KG QM IGP KWXK KWCT PXT
# T__ __A_ _O_ ON _A__I__:  TO __T__
# KWM OMXA RGB GH NXIECIY:  KG MIKMO
# A _O___ U__I__ T__ O__ _OU NI__
# X PGOAN ZIACJM KWM GIM BGZ HCIN
# _OU____N BU______ _IT_, A__ _O__
# BGZOTMAH LZONMIMN PCKW, XIN QGSM
# _OU_ BO__ TO_A__ _OT_I__ BUT A
# BGZO LGNB KGPXON IGKWCIY LZK X
# __A___ T_AT TI__ _I__T __O_
# DOXBMO KWXK KCQM QCYWK TAGP
# _O__.
# NGPI.
#
# 	Key {'X': 'A', 'C': 'I', 'K': 'T', 'G': 'O', 'H': 'F', 'W': 'H', 'M': 'E', 'I': 'N', 'N': 'D', 'L': 'B', 'Z': 'U'} ::
# 	Utility of 0.578 present in the puzzle
#
# IT O__U__ TO _E NO_ THAT THI_ _A_
# CK GEEZOT KG QM IGP KWXK KWCT PXT
# THE _EA_ _O_ OF DAN_IN_:  TO ENTE_
# KWM OMXA RGB GH NXIECIY:  KG MIKMO
# A _O__D UN_I_E THE ONE _OU FIND
# X PGOAN ZIACJM KWM GIM BGZ HCIN
# _OU__E_F BU_DENED _ITH, AND _O_E
# BGZOTMAH LZONMIMN PCKW, XIN QGSM
# _OU_ BOD_ TO_A_D NOTHIN_ BUT A
# BGZO LGNB KGPXON IGKWCIY LZK X
# __A_E_ THAT TI_E _I_HT __O_
# DOXBMO KWXK KCQM QCYWK TAGP
# DO_N.
# NGPI.
#
# 	Key {'X': 'A', 'C': 'I', 'K': 'T', 'G': 'O', 'H': 'F', 'W': 'H', 'M': 'E', 'L': 'B', 'Z': 'U'} ::
# 	Utility of 0.474 present in the puzzle
#
# IT O__U__ TO _E _O_ THAT THI_ _A_
# CK GEEZOT KG QM IGP KWXK KWCT PXT
# THE _EA_ _O_ OF _A__I__:  TO E_TE_
# KWM OMXA RGB GH NXIECIY:  KG MIKMO
# A _O___ U__I_E THE O_E _OU FI__
# X PGOAN ZIACJM KWM GIM BGZ HCIN
# _OU__E_F BU__E_E_ _ITH, A__ _O_E
# BGZOTMAH LZONMIMN PCKW, XIN QGSM
# _OU_ BO__ TO_A__ _OTHI__ BUT A
# BGZO LGNB KGPXON IGKWCIY LZK X
# __A_E_ THAT TI_E _I_HT __O_
# DOXBMO KWXK KCQM QCYWK TAGP
# _O__.
# NGPI.
#
# 	Key {'X': 'A', 'C': 'I', 'K': 'T', 'G': 'O', 'H': 'F', 'I': 'N', 'N': 'D', 'L': 'B', 'Z': 'U'} ::
# 	Utility of 0.36 present in the puzzle
#
# IT O__U__ TO __ NO_ T_AT T_I_ _A_
# CK GEEZOT KG QM IGP KWXK KWCT PXT
# T__ __A_ _O_ OF DAN_IN_:  TO _NT__
# KWM OMXA RGB GH NXIECIY:  KG MIKMO
# A _O__D UN_I__ T__ ON_ _OU FIND
# X PGOAN ZIACJM KWM GIM BGZ HCIN
# _OU____F BU_D_N_D _IT_, AND _O__
# BGZOTMAH LZONMIMN PCKW, XIN QGSM
# _OU_ BOD_ TO_A_D NOT_IN_ BUT A
# BGZO LGNB KGPXON IGKWCIY LZK X
# __A___ T_AT TI__ _I__T __O_
# DOXBMO KWXK KCQM QCYWK TAGP
# DO_N.
# NGPI.
