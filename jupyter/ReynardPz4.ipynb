# %% [markdown]
# # Reynard
#
# ### Anthony Sheller <br> EN.605.745<br>Reasoning Under Uncertainty
#
# ### Puzzle 4

# %%
# This lets me import the Python modules from the directory below this one
import sys
sys.path.insert(0, '../../reynard')


from pylab import *
import matplotlib.pyplot as plt
import os
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
from puzzle import Puzzle
from agent import Agent
from reynard_constants import *
import operator
from time import time,sleep
from datetime import timedelta

# %%
class PZ4_EVAL:

    def __init__(self,puzzle):

        agent = Agent(puzzle)
        self.agent = agent
        agent.VERBOSE = False
        agent.startPuzzle()
        print("Puzzle 4")
        if agent.puzzle.wordsOfLength(1):
            if not agent.puzzle.bothAandI():
                for ltr in ['A','I']:
                    agent.assignAorI(agent.root, ltr)
            else:
                agent.assignAorI(agent.root, ['A','I'])
            agent.twoLtWdsBeginWithAorI()  

        startTime = time()
        if agent.puzzle.wordsOfLength(2):
            startTime = time()
            if len(agent.root.children) == 0:
                agent.processTwoLetterWords(agent.root,0,5)
            endTime = time()
            elapsed = endTime - startTime
            elapsedTwo = str(timedelta(seconds=elapsed))
            print("Puzzle 4 -- Execution time for two letter words is {}".format(elapsedTwo))  
            maxVal = max(self.getHighestUtility(agent.root,[]))
            print("Puzzle 4 -- Maximum Utility is {}".format(round(maxVal,3)))
            print("Puzzle 4  -- Node Count at {}".format(agent.node_count))
            self.evaluateChildrenForKey(agent.root, False)
            self.evaluateChildrenForKeyThree(agent.root,returnValue =False)
            
        startTime = time()
        if agent.puzzle.wordsOfLength(3):
            startTime = time()
            agent.processThreeLetterWords(agent.root,0,5)
            endTime = time()
            elapsed = endTime - startTime
            elapsedTwo = str(timedelta(seconds=elapsed))
            print("Puzzle 4 -- Execution time for three letter words is {}".format(elapsedTwo))  
            maxVal = max(self.getHighestUtility(agent.root,[]))
            print("Puzzle 4 -- Maximum Utility is {}".format(round(maxVal,3)))
            print("Puzzle 4  -- Node Count at {}".format(agent.node_count))
            self.evaluateChildrenForKey(agent.root, False)
            self.evaluateChildrenForKeyThree(agent.root,returnValue =False)
            

    def evaluateChildrenForKey(self,node,returnValue):
        '''
        Helper function for the tests 
        '''
        if len(node.children) > 0: 
            for child in node.children:
                self.evaluateChildrenForKey(child,returnValue)
        else:
           returnValue = self.checkkeyTwoLetters(node)
        return returnValue

    def evaluateChildrenForKeyThree(self,node,returnValue):
        '''
        Helper function for the tests 
        '''
        if len(node.children) > 0: 
            for child in node.children:
                self.evaluateChildrenForKeyThree(child,returnValue)
        else:
           returnValue = self.checkkeyMoreLetters(node)
        return returnValue       

    def checkkeyTwoLetters(self,node):
        '''
        Helper function for the tests
        '''
        returnVal = False
        if all([k in list(node.letter.keys()) for k in list('MX') ]):
            if node.letter['M'] == 'T':
                if node.letter['X'] == 'O':
                    print("\n\tKey {} :: \n\tUtility of {} present in the puzzle\n".format(node.letter,round(node.utility,3)))
                    self.agent.showProgressPuzzle(node)
        # Leaving the system stack and not finding what we want
        return returnVal

    def checkkeyMoreLetters(self,node):
        '''
        Helper function for the tests
        '''
        returnVal = False
        if all([k in list(node.letter.keys()) for k in list('MXPL') ]):
            if node.letter['M'] == 'T':
                if node.letter['X'] == 'O':
                    if node.letter['P'] == 'H':
                        if node.letter['L'] == 'E':
                            print("\n\tKey {} :: \n\tUtility of {} present in the puzzle\n".format(node.letter,round(node.utility,3)))
                            self.agent.showProgressPuzzle(node)
        # Leaving the system stack and not finding what we were
        return returnVal

    def getHighestUtility(self,node,maxVal=[]):
        '''
        What is the highest utility in the tree
        '''
        if len(node.children) > 0: 
            for child in node.children:
                self.getHighestUtility(child,maxVal)    
        else:
            maxVal.append(node.utility)
        return maxVal

# %%
PUZZLE = Puzzle('../data/pz4.txt')
pz4_eval = PZ4_EVAL(PUZZLE)
# Out:
# Puzzle 4
# Puzzle 4 -- Execution time for two letter words is 0:00:19.223415
# Puzzle 4 -- Maximum Utility is 0.167
# Puzzle 4  -- Node Count at 185
#
# 	Key {'C': 'I', 'L': 'N', 'M': 'T', 'X': 'O'} ::
# 	Utility of 0.139 present in the puzzle
#
# IN ___'T _____N T_N N_N_T_ O_ O__ ___N_. T_N_
# CL KFU'M KPFUTL MPL LNLUMR XE XYQ IZNLR. MPLD
# ____N_, ___ T_N_N T_N_ __N. __T T_N ___N_ IN
# PFAALU, FUW MPLQL MPLD FQL. SYM MPL IZULR CL
# ___I TO _O__N_T T_O_N N_N_T_, T_N ____N_ IN
# WQFC MX KXUULKM MPXRL LNLUMR, MPL RPFALR CL
# ___N ___ T_N _O______O__ IN
# VFOL FUW MPL KXUKIYRZXUR CL
# _N___, T_O_N _O_N __O_ __.
# QLFKP, MPXRL KXVL EQXV YR.
#
# 	Key {'C': 'I', 'L': 'S', 'M': 'T', 'X': 'O', 'E': 'N'} ::
# 	Utility of 0.167 present in the puzzle
#
# IS ___'T _____S T_S S_S_T_ ON O__ ___S_. T_S_
# CL KFU'M KPFUTL MPL LNLUMR XE XYQ IZNLR. MPLD
# ____S_, ___ T_S_S T_S_ __S. __T T_S ___S_ IS
# PFAALU, FUW MPLQL MPLD FQL. SYM MPL IZULR CL
# ___I TO _O__S_T T_O_S S_S_T_, T_S ____S_ IS
# WQFC MX KXUULKM MPXRL LNLUMR, MPL RPFALR CL
# ___S ___ T_S _O______O__ IS
# VFOL FUW MPL KXUKIYRZXUR CL
# _S___, T_O_S _O_S N_O_ __.
# QLFKP, MPXRL KXVL EQXV YR.
# Puzzle 4 -- Execution time for three letter words is 0:01:41.886453
# Puzzle 4 -- Maximum Utility is 0.479
# Puzzle 4  -- Node Count at 33
#
# 	Key {'C': 'I', 'L': 'N', 'X': 'O', 'E': 'F', 'F': 'A', 'U': 'R', 'W': 'E', 'S': 'B', 'Y': 'U', 'M': 'T'} ::
# 	Utility of 0.357 present in the puzzle
#
# IN _AR'T __AR_N T_N N_NRT_ OF OU_ ___N_. T_N_
# CL KFU'M KPFUTL MPL LNLUMR XE XYQ IZNLR. MPLD
# _A__NR, ARE T_N_N T_N_ A_N. BUT T_N __RN_ IN
# PFAALU, FUW MPLQL MPLD FQL. SYM MPL IZULR CL
# E_AI TO _ORRN_T T_O_N N_NRT_, T_N __A_N_ IN
# WQFC MX KXUULKM MPXRL LNLUMR, MPL RPFALR CL
# _A_N ARE T_N _OR__U__OR_ IN
# VFOL FUW MPL KXUKIYRZXUR CL
# _NA__, T_O_N _O_N F_O_ U_.
# QLFKP, MPXRL KXVL EQXV YR.
#
# 	Key {'C': 'I', 'L': 'N', 'M': 'T', 'X': 'O', 'F': 'A', 'U': 'R', 'W': 'E', 'S': 'B', 'Y': 'U'} ::
# 	Utility of 0.333 present in the puzzle
#
# IN _AR'T __AR_N T_N N_NRT_ O_ OU_ ___N_. T_N_
# CL KFU'M KPFUTL MPL LNLUMR XE XYQ IZNLR. MPLD
# _A__NR, ARE T_N_N T_N_ A_N. BUT T_N __RN_ IN
# PFAALU, FUW MPLQL MPLD FQL. SYM MPL IZULR CL
# E_AI TO _ORRN_T T_O_N N_NRT_, T_N __A_N_ IN
# WQFC MX KXUULKM MPXRL LNLUMR, MPL RPFALR CL
# _A_N ARE T_N _OR__U__OR_ IN
# VFOL FUW MPL KXUKIYRZXUR CL
# _NA__, T_O_N _O_N __O_ U_.
# QLFKP, MPXRL KXVL EQXV YR.
#
# 	Key {'C': 'I', 'L': 'S', 'X': 'O', 'E': 'F', 'F': 'A', 'U': 'N', 'W': 'D', 'S': 'B', 'Y': 'U', 'M': 'T'} ::
# 	Utility of 0.357 present in the puzzle
#
# IS _AN'T __AN_S T_S S_SNT_ OF OU_ ___S_. T_S_
# CL KFU'M KPFUTL MPL LNLUMR XE XYQ IZNLR. MPLD
# _A__SN, AND T_S_S T_S_ A_S. BUT T_S __NS_ IS
# PFAALU, FUW MPLQL MPLD FQL. SYM MPL IZULR CL
# D_AI TO _ONNS_T T_O_S S_SNT_, T_S __A_S_ IS
# WQFC MX KXUULKM MPXRL LNLUMR, MPL RPFALR CL
# _A_S AND T_S _ON__U__ON_ IS
# VFOL FUW MPL KXUKIYRZXUR CL
# _SA__, T_O_S _O_S F_O_ U_.
# QLFKP, MPXRL KXVL EQXV YR.
#
# 	Key {'C': 'I', 'L': 'S', 'X': 'O', 'E': 'F', 'F': 'A', 'U': 'R', 'W': 'E', 'S': 'B', 'Y': 'U', 'M': 'T'} ::
# 	Utility of 0.357 present in the puzzle
#
# IS _AR'T __AR_S T_S S_SRT_ OF OU_ ___S_. T_S_
# CL KFU'M KPFUTL MPL LNLUMR XE XYQ IZNLR. MPLD
# _A__SR, ARE T_S_S T_S_ A_S. BUT T_S __RS_ IS
# PFAALU, FUW MPLQL MPLD FQL. SYM MPL IZULR CL
# E_AI TO _ORRS_T T_O_S S_SRT_, T_S __A_S_ IS
# WQFC MX KXUULKM MPXRL LNLUMR, MPL RPFALR CL
# _A_S ARE T_S _OR__U__OR_ IS
# VFOL FUW MPL KXUKIYRZXUR CL
# _SA__, T_O_S _O_S F_O_ U_.
# QLFKP, MPXRL KXVL EQXV YR.
#
# 	Key {'C': 'I', 'L': 'S', 'M': 'T', 'X': 'O', 'E': 'N', 'F': 'A', 'U': 'R', 'W': 'E', 'S': 'B', 'Y': 'U'} ::
# 	Utility of 0.357 present in the puzzle
#
# IS _AR'T __AR_S T_S S_SRT_ ON OU_ ___S_. T_S_
# CL KFU'M KPFUTL MPL LNLUMR XE XYQ IZNLR. MPLD
# _A__SR, ARE T_S_S T_S_ A_S. BUT T_S __RS_ IS
# PFAALU, FUW MPLQL MPLD FQL. SYM MPL IZULR CL
# E_AI TO _ORRS_T T_O_S S_SRT_, T_S __A_S_ IS
# WQFC MX KXUULKM MPXRL LNLUMR, MPL RPFALR CL
# _A_S ARE T_S _OR__U__OR_ IS
# VFOL FUW MPL KXUKIYRZXUR CL
# _SA__, T_O_S _O_S N_O_ U_.
# QLFKP, MPXRL KXVL EQXV YR.
