# %%
# This lets me import the Python modules from the directory below this one
import sys
sys.path.insert(0, '../../reynard')


from pylab import *
import matplotlib.pyplot as plt
import os
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

# %%
# a-0 b-1 c-2 d-3 e-4 f-5 g-6 h-7 i-8 j-9 k-10
bn = gum.fastBN("0->3<-1;3<-2->4;5->7<-3;3->8;3->9;6->10<-4")

# %%
bn
# Out:
# (pyAgrum.BayesNet<double>@0x56089b84c1f0) BN{nodes: 11, arcs: 10, domainSize: 2048, dim: 54}

# %%
jtg= gum.JunctionTreeGenerator()

# %%
jtg.binaryJoinTree(bn)
# Out:
# <pyAgrum.pyAgrum.CliqueGraph; proxy of <Swig Object of type 'gum::CliqueGraph *' at 0x7f03f9216fc0> >

# %%
bnj.ju

# %%
bn=gum.fastBN("0->1->2<-3->4->5->6<-2->7")
jtg=gum.JunctionTreeGenerator()

# %%
gnb.showBN(rbn.bn,size=f"20")

# %%
gnb.showBN(bn,size=f"20")

# %%
jtg.eliminationOrder(bn)

# %%
nb = jtg.binaryJoinTree(bn)

# %%
gnb.showJunctionTree(jtg.junctionTree(bn))

# %%
jt = ie.
