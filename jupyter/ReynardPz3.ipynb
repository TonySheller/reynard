# %% [markdown]
# # Reynard
#
# ### Anthony Sheller <br> EN.605.745<br>Reasoning Under Uncertainty
#
# ### Puzzle 3

# %%
# This lets me import the Python modules from the directory below this one
import sys
sys.path.insert(0, '../../reynard')


from pylab import *
import matplotlib.pyplot as plt
import os
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
from puzzle import Puzzle
from agent import Agent
from reynard_constants import *
import operator
from time import time,sleep
from datetime import timedelta

# %%
class PZ3_EVAL:

    def __init__(self,puzzle):

        agent = Agent(puzzle)
        self.agent = agent
        agent.VERBOSE = False
        agent.startPuzzle()
        print("Puzzle 1")
        if agent.puzzle.wordsOfLength(1):
            if not agent.puzzle.bothAandI():
                for ltr in ['A','I']:
                    agent.assignAorI(agent.root, ltr)
            else:
                agent.assignAorI(agent.root, ['A','I'])
            agent.twoLtWdsBeginWithAorI()  

        startTime = time()
        if agent.puzzle.wordsOfLength(2):
            startTime = time()
            for child in agent.root.children:
                agent.processTwoLetterWords(child,0,8)
            endTime = time()
            elapsed = endTime - startTime
            elapsedTwo = str(timedelta(seconds=elapsed))
            print("Puzzle 3 -- Execution time for two letter words is {}".format(elapsedTwo))  
            maxVal = max(self.getHighestUtility(agent.root,[]))
            print("Puzzle 3 -- Maximum Utility is {}".format(round(maxVal,3)))
            print("Puzzle 3  -- Node Count at {}".format(agent.node_count))
            self.evaluateChildrenForKey(agent.root, False)
            self.evaluateChildrenForKeyThree(agent.root,returnValue =False)
            
        startTime = time()
        if agent.puzzle.wordsOfLength(3):
            startTime = time()
            for child in agent.root.children:
                agent.processThreeLetterWords(child,0,5)
            endTime = time()
            elapsed = endTime - startTime
            elapsedTwo = str(timedelta(seconds=elapsed))
            print("Puzzle 3 -- Execution time for three letter words is {}".format(elapsedTwo))  
            maxVal = max(self.getHighestUtility(agent.root,[]))
            print("Puzzle 3 -- Maximum Utility is {}".format(round(maxVal,3)))
            print("Puzzle 3  -- Node Count at {}".format(agent.node_count))
            self.evaluateChildrenForKey(agent.root, False)
            self.evaluateChildrenForKeyThree(agent.root,returnValue =False)
            

    def evaluateChildrenForKey(self,node,returnValue):
        '''
        Helper function for the tests 
        '''
        if len(node.children) > 0: 
            for child in node.children:
                self.evaluateChildrenForKey(child,returnValue)
        else:
           returnValue = self.checkkeyTwoLetters(node)
        return returnValue

    def evaluateChildrenForKeyThree(self,node,returnValue):
        '''
        Helper function for the tests 
        '''
        if len(node.children) > 0: 
            for child in node.children:
                self.evaluateChildrenForKeyThree(child,returnValue)
        else:
           returnValue = self.checkkeyMoreLetters(node)
        return returnValue       

    def checkkeyTwoLetters(self,node):
        '''
        Helper function for the tests
        '''
        returnVal = False
        if all([k in list(node.letter.keys()) for k in list('TQHE') ]):
                if node.letter['T'] == 'I':
                    if node.letter['Q'] == 'T':
                        if node.letter['H'] == 'O':
                            if node.letter['E'] == 'D':
                                print("\n\tKey {} :: \n\tUtility of {} present in the puzzle\n".format(node.letter,round(node.utility,3)))
                                self.agent.showProgressPuzzle(node)
        # Leaving the system stack and not finding what we want
        return returnVal

    def checkkeyMoreLetters(self,node):
        '''
        Helper function for the tests
        '''
        returnVal = False
        if all([k in list(node.letter.keys()) for k in list('TQHEDOK') ]):
                if node.letter['T'] == 'I':
                    if node.letter['Q'] == 'T':
                        if node.letter['H'] == 'O':
                            if node.letter['E'] == 'D':
                                if node.letter['D'] == 'A':
                                    if node.letter['O'] =='R':
                                        if node.letter['K'] == 'F':
                                            print("\n\tBigger Key {} :: \n\tUtility of {}  present in the puzzle\n".format(node.letter,round(node.utility,3)))
                                            self.agent.showProgressPuzzle(node)
        # Leaving the system stack and not finding what we were
        return returnVal

    def getHighestUtility(self,node,maxVal=[]):
        '''
        What is the highest utility in the tree
        '''
        if len(node.children) > 0: 
            for child in node.children:
                self.getHighestUtility(child,maxVal)    
        else:
            maxVal.append(node.utility)
        return maxVal

# %%
PUZZLE = Puzzle('../data/pz3.txt')
pz3_eval = PZ3_EVAL(PUZZLE)
# Out:
# Puzzle 1
#
#
# ****0****
#
#
#  TIME ELAPSED IS 0:00:00.055810
#
#
# ****1****
#
#
#  TIME ELAPSED IS 0:00:00.106160
#
#
# ****0****
#
#
#  TIME ELAPSED IS 0:00:00.074078
#
#
# ****1****
#
#
#  TIME ELAPSED IS 0:00:00.054162
# Puzzle 3 -- Execution time for two letter words is 0:00:00.290855
# Puzzle 3 -- Maximum Utility is 0.194
# Puzzle 3  -- Node Count at 19
#
# 	Key {'T': 'I', 'Q': 'T', 'H': 'O', 'E': 'D'} ::
# 	Utility of 0.147 present in the puzzle
#
# __D____ _O__ __D ______I_TIO_ TO
# CFEBCVV BHPC DFE DSSOCZTDQTHF QH
# ___T__D___ __O ___ _I__ "I ___
# LDOQCFECOV MRH DOC BTIC "T VCC
# T__T _O_'__ D_I__I__ _T__I__T
# QRDQ AHW'OC EOTFITFJ VQODTJRQ
# __I____ __T DO _O_ ___T TO
# MRTVICA LWQ EH AHW MDFQ QH
# ______ T_I_ D_I__I_I?" T____ _O_
# VDGSBC QRTV EDTNWTOT?" QRDFI AHW
# _O_ ___O__I_I__ T__T I _O_T_I_
# KHO OCZHJFTYTFJ QRDQ T ZHFQDTF
# ___TIT_D__.
# GWBQTQWECV.
# Puzzle 3 -- Execution time for three letter words is 0:00:10.739488
# Puzzle 3 -- Maximum Utility is 0.478
# Puzzle 3  -- Node Count at 11
#
# 	Key {'T': 'I', 'Q': 'T', 'H': 'O', 'E': 'D', 'D': 'A', 'F': 'N', 'L': 'B', 'W': 'U'} ::
# 	Utility of 0.289 present in the puzzle
#
# _ND____ _O__ AND A_____IATION TO
# CFEBCVV BHPC DFE DSSOCZTDQTHF QH
# BA_T_ND___ __O A__ _I__ "I ___
# LDOQCFECOV MRH DOC BTIC "T VCC
# T_AT _OU'__ D_IN_IN_ _T_AI__T
# QRDQ AHW'OC EOTFITFJ VQODTJRQ
# __I____ BUT DO _OU _ANT TO
# MRTVICA LWQ EH AHW MDFQ QH
# _A____ T_I_ DAI_UI_I?" T_AN_ _OU
# VDGSBC QRTV EDTNWTOT?" QRDFI AHW
# _O_ ___O_NI_IN_ T_AT I _ONTAIN
# KHO OCZHJFTYTFJ QRDQ T ZHFQDTF
# _U_TITUD__.
# GWBQTQWECV.
#
# 	Key {'T': 'I', 'Q': 'T', 'H': 'O', 'E': 'D', 'D': 'A', 'O': 'R', 'C': 'E', 'R': 'H', 'L': 'B', 'W': 'U', 'K': 'F'} ::
# 	Utility of 0.478 present in the puzzle
#
# E_D_E__ _O_E A_D A__RE_IATIO_ TO
# CFEBCVV BHPC DFE DSSOCZTDQTHF QH
# BARTE_DER_ _HO ARE _I_E "I _EE
# LDOQCFECOV MRH DOC BTIC "T VCC
# THAT _OU'RE DRI__I__ _TRAI_HT
# QRDQ AHW'OC EOTFITFJ VQODTJRQ
# _HI__E_ BUT DO _OU _A_T TO
# MRTVICA LWQ EH AHW MDFQ QH
# _A___E THI_ DAI_UIRI?" THA__ _OU
# VDGSBC QRTV EDTNWTOT?" QRDFI AHW
# FOR RE_O__I_I__ THAT I _O_TAI_
# KHO OCZHJFTYTFJ QRDQ T ZHFQDTF
# _U_TITUDE_.
# GWBQTQWECV.
#
# 	Key {'T': 'I', 'Q': 'T', 'H': 'O', 'E': 'D', 'D': 'A', 'O': 'R', 'C': 'E', 'R': 'H', 'K': 'F'} ::
# 	Utility of 0.432 present in the puzzle
#
# E_D_E__ _O_E A_D A__RE_IATIO_ TO
# CFEBCVV BHPC DFE DSSOCZTDQTHF QH
# _ARTE_DER_ _HO ARE _I_E "I _EE
# LDOQCFECOV MRH DOC BTIC "T VCC
# THAT _O_'RE DRI__I__ _TRAI_HT
# QRDQ AHW'OC EOTFITFJ VQODTJRQ
# _HI__E_ __T DO _O_ _A_T TO
# MRTVICA LWQ EH AHW MDFQ QH
# _A___E THI_ DAI__IRI?" THA__ _O_
# VDGSBC QRTV EDTNWTOT?" QRDFI AHW
# FOR RE_O__I_I__ THAT I _O_TAI_
# KHO OCZHJFTYTFJ QRDQ T ZHFQDTF
# ___TIT_DE_.
# GWBQTQWECV.
#
# 	Key {'T': 'I', 'Q': 'T', 'H': 'O', 'E': 'D', 'D': 'A', 'O': 'R', 'C': 'E', 'L': 'B', 'W': 'U', 'K': 'F'} ::
# 	Utility of 0.35 present in the puzzle
#
# E_D_E__ _O_E A_D A__RE_IATIO_ TO
# CFEBCVV BHPC DFE DSSOCZTDQTHF QH
# BARTE_DER_ __O ARE _I_E "I _EE
# LDOQCFECOV MRH DOC BTIC "T VCC
# T_AT _OU'RE DRI__I__ _TRAI__T
# QRDQ AHW'OC EOTFITFJ VQODTJRQ
# __I__E_ BUT DO _OU _A_T TO
# MRTVICA LWQ EH AHW MDFQ QH
# _A___E T_I_ DAI_UIRI?" T_A__ _OU
# VDGSBC QRTV EDTNWTOT?" QRDFI AHW
# FOR RE_O__I_I__ T_AT I _O_TAI_
# KHO OCZHJFTYTFJ QRDQ T ZHFQDTF
# _U_TITUDE_.
# GWBQTQWECV.
#
# 	Key {'T': 'I', 'Q': 'T', 'H': 'O', 'E': 'D', 'D': 'A', 'O': 'R', 'C': 'E', 'K': 'F'} ::
# 	Utility of 0.289 present in the puzzle
#
# E_D_E__ _O_E A_D A__RE_IATIO_ TO
# CFEBCVV BHPC DFE DSSOCZTDQTHF QH
# _ARTE_DER_ __O ARE _I_E "I _EE
# LDOQCFECOV MRH DOC BTIC "T VCC
# T_AT _O_'RE DRI__I__ _TRAI__T
# QRDQ AHW'OC EOTFITFJ VQODTJRQ
# __I__E_ __T DO _O_ _A_T TO
# MRTVICA LWQ EH AHW MDFQ QH
# _A___E T_I_ DAI__IRI?" T_A__ _O_
# VDGSBC QRTV EDTNWTOT?" QRDFI AHW
# FOR RE_O__I_I__ T_AT I _O_TAI_
# KHO OCZHJFTYTFJ QRDQ T ZHFQDTF
# ___TIT_DE_.
# GWBQTQWECV.
#
# 	Bigger Key {'T': 'I', 'Q': 'T', 'H': 'O', 'E': 'D', 'D': 'A', 'O': 'R', 'C': 'E', 'R': 'H', 'L': 'B', 'W': 'U', 'K': 'F'} ::
# 	Utility of 0.478  present in the puzzle
#
# E_D_E__ _O_E A_D A__RE_IATIO_ TO
# CFEBCVV BHPC DFE DSSOCZTDQTHF QH
# BARTE_DER_ _HO ARE _I_E "I _EE
# LDOQCFECOV MRH DOC BTIC "T VCC
# THAT _OU'RE DRI__I__ _TRAI_HT
# QRDQ AHW'OC EOTFITFJ VQODTJRQ
# _HI__E_ BUT DO _OU _A_T TO
# MRTVICA LWQ EH AHW MDFQ QH
# _A___E THI_ DAI_UIRI?" THA__ _OU
# VDGSBC QRTV EDTNWTOT?" QRDFI AHW
# FOR RE_O__I_I__ THAT I _O_TAI_
# KHO OCZHJFTYTFJ QRDQ T ZHFQDTF
# _U_TITUDE_.
# GWBQTQWECV.
#
# 	Bigger Key {'T': 'I', 'Q': 'T', 'H': 'O', 'E': 'D', 'D': 'A', 'O': 'R', 'C': 'E', 'R': 'H', 'K': 'F'} ::
# 	Utility of 0.432  present in the puzzle
#
# E_D_E__ _O_E A_D A__RE_IATIO_ TO
# CFEBCVV BHPC DFE DSSOCZTDQTHF QH
# _ARTE_DER_ _HO ARE _I_E "I _EE
# LDOQCFECOV MRH DOC BTIC "T VCC
# THAT _O_'RE DRI__I__ _TRAI_HT
# QRDQ AHW'OC EOTFITFJ VQODTJRQ
# _HI__E_ __T DO _O_ _A_T TO
# MRTVICA LWQ EH AHW MDFQ QH
# _A___E THI_ DAI__IRI?" THA__ _O_
# VDGSBC QRTV EDTNWTOT?" QRDFI AHW
# FOR RE_O__I_I__ THAT I _O_TAI_
# KHO OCZHJFTYTFJ QRDQ T ZHFQDTF
# ___TIT_DE_.
# GWBQTQWECV.
#
# 	Bigger Key {'T': 'I', 'Q': 'T', 'H': 'O', 'E': 'D', 'D': 'A', 'O': 'R', 'C': 'E', 'L': 'B', 'W': 'U', 'K': 'F'} ::
# 	Utility of 0.35  present in the puzzle
#
# E_D_E__ _O_E A_D A__RE_IATIO_ TO
# CFEBCVV BHPC DFE DSSOCZTDQTHF QH
# BARTE_DER_ __O ARE _I_E "I _EE
# LDOQCFECOV MRH DOC BTIC "T VCC
# T_AT _OU'RE DRI__I__ _TRAI__T
# QRDQ AHW'OC EOTFITFJ VQODTJRQ
# __I__E_ BUT DO _OU _A_T TO
# MRTVICA LWQ EH AHW MDFQ QH
# _A___E T_I_ DAI_UIRI?" T_A__ _OU
# VDGSBC QRTV EDTNWTOT?" QRDFI AHW
# FOR RE_O__I_I__ T_AT I _O_TAI_
# KHO OCZHJFTYTFJ QRDQ T ZHFQDTF
# _U_TITUDE_.
# GWBQTQWECV.
#
# 	Bigger Key {'T': 'I', 'Q': 'T', 'H': 'O', 'E': 'D', 'D': 'A', 'O': 'R', 'C': 'E', 'K': 'F'} ::
# 	Utility of 0.289  present in the puzzle
#
# E_D_E__ _O_E A_D A__RE_IATIO_ TO
# CFEBCVV BHPC DFE DSSOCZTDQTHF QH
# _ARTE_DER_ __O ARE _I_E "I _EE
# LDOQCFECOV MRH DOC BTIC "T VCC
# T_AT _O_'RE DRI__I__ _TRAI__T
# QRDQ AHW'OC EOTFITFJ VQODTJRQ
# __I__E_ __T DO _O_ _A_T TO
# MRTVICA LWQ EH AHW MDFQ QH
# _A___E T_I_ DAI__IRI?" T_A__ _O_
# VDGSBC QRTV EDTNWTOT?" QRDFI AHW
# FOR RE_O__I_I__ T_AT I _O_TAI_
# KHO OCZHJFTYTFJ QRDQ T ZHFQDTF
# ___TIT_DE_.
# GWBQTQWECV.
