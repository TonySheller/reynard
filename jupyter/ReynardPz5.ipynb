# %% [markdown]
# # Reynard
#
# ### Anthony Sheller <br> EN.605.745<br>Reasoning Under Uncertainty
#
# ### Puzzle 5

# %%
# This lets me import the Python modules from the directory below this one
import sys
sys.path.insert(0, '../../reynard')


from pylab import *
import matplotlib.pyplot as plt
import os
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
from puzzle import Puzzle
from agent import Agent
from reynard_constants import *
import operator
from time import time,sleep
from datetime import timedelta

# %%
class PZ5_EVAL:

    def __init__(self,puzzle):

        agent = Agent(puzzle)
        self.agent = agent
        agent.VERBOSE = False
        agent.startPuzzle()
        print("Puzzle 5")
        if agent.puzzle.wordsOfLength(1):
            if not agent.puzzle.bothAandI():
                for ltr in ['A','I']:
                    agent.assignAorI(agent.root, ltr)
            else:
                agent.assignAorI(agent.root, ['A','I'])
            agent.twoLtWdsBeginWithAorI()  

        startTime = time()
        if agent.puzzle.wordsOfLength(2):
            startTime = time()
            for child in agent.root.children:
                agent.processTwoLetterWords(child,0,5)
            endTime = time()
            elapsed = endTime - startTime
            elapsedTwo = str(timedelta(seconds=elapsed))
            print("Puzzle 1 -- Execution time for two letter words is {}".format(elapsedTwo))  
            maxVal = max(self.getHighestUtility(agent.root,[]))
            print("Puzzle 1 -- Maximum Utility is {}".format(round(maxVal,3)))
            print("Puzzle 1  -- Node Count at {}".format(agent.node_count))
            self.evaluateChildrenForKey(agent.root, False)
            self.evaluateChildrenForKeyThree(agent.root,returnValue =False)
            
        startTime = time()
        if agent.puzzle.wordsOfLength(3):
            startTime = time()
            for child in agent.root.children:
                agent.processThreeLetterWords(child,0,5)
            endTime = time()
            elapsed = endTime - startTime
            elapsedTwo = str(timedelta(seconds=elapsed))
            print("Puzzle 1 -- Execution time for three letter words is {}".format(elapsedTwo))  
            maxVal = max(self.getHighestUtility(agent.root,[]))
            print("Puzzle 1 -- Maximum Utility is {}".format(round(maxVal,3)))
            print("Puzzle 1  -- Node Count at {}".format(agent.node_count))
            self.evaluateChildrenForKey(agent.root, False)
            self.evaluateChildrenForKeyThree(agent.root,returnValue =False)
            


    def evaluateChildrenForKey(self,node,returnValue):
        '''
        Helper function for the tests 
        '''
        if len(node.children) > 0: 
            for child in node.children:
                self.evaluateChildrenForKey(child,returnValue)
        else:
           returnValue = self.checkkeyTwoLetters(node)
        return returnValue

    def evaluateChildrenForKeyThree(self,node,returnValue):
        '''
        Helper function for the tests 
        '''
        if len(node.children) > 0: 
            for child in node.children:
                self.evaluateChildrenForKeyThree(child,returnValue)
        else:
           returnValue = self.checkkeyMoreLetters(node)
        return returnValue       

    def checkkeyTwoLetters(self,node):
        '''
        Helper function for the tests
        '''
        returnVal = False
        if all([k in list(node.letter.keys()) for k in list('CG') ]):

            if node.letter['C'] == 'I':
                if node.letter['G'] == 'T':
                    print("\n\tKey {} :: \n\tUtility of {} present in the puzzle\n".format(node.letter,round(node.utility,3)))
                    self.agent.showProgressPuzzle(node)
        # Leaving the system stack and not finding what we want
        return returnVal

    def checkkeyMoreLetters(self,node):
        '''
        Helper function for the tests
        '''
        returnVal = False
        if all([k in list(node.letter.keys()) for k in list('CGRM') ]):
            if node.letter['C'] == 'I':
                if node.letter['G'] == 'T':
                    if node.letter['R'] == 'A':
                        if node.letter['M'] == 'N':
                            print("\n\tKey {} :: \n\tUtility of {} present in the puzzle\n".format(node.letter,round(node.utility,3)))
                            self.agent.showProgressPuzzle(node)
        # Leaving the system stack and not finding what we were
        return returnVal

    def getHighestUtility(self,node,maxVal=[]):
        '''
        What is the highest utility in the tree
        '''
        if len(node.children) > 0: 
            for child in node.children:
                self.getHighestUtility(child,maxVal)    
        else:
            maxVal.append(node.utility)
        return maxVal

# %%
PUZZLE = Puzzle('../data/pz5.txt')
pz5_eval = PZ5_EVAL(PUZZLE)
# Out:
# Puzzle 5
# Puzzle 1 -- Execution time for two letter words is 0:00:12.571406
# Puzzle 1 -- Maximum Utility is 0.25
# Puzzle 1  -- Node Count at 147
#
# 	Key {'R': 'A', 'C': 'I', 'M': 'S', 'G': 'T', 'H': 'O', 'W': 'F'} ::
# 	Utility of 0.214 present in the puzzle
#
# ____'_ T__ T_IS_ A___T
# IOUO'Q GIO GICMX RADEG
# IOA_ISATI_S. IT _I___ F__ AS
# CHRXCMRGCDM. CG XCPOQ WDE RM
# _____T_SITF T_ ___AO, S_ OATT__,
# DYYDUGEMCGW GD VUORH, MD HRGGOU,
# F__ _S__, ___ __T_AS_I__ OF
# WDE JMDT, IDT DEGNRMVCQI HW
# ___AO_ ____. _I__, I T_____T I _A_
# VUORHQ TOUO. NCJO, C GIDEXIG C TRQ
# __IS_ T_ __AF IS T__ S_A. I _A_ A
# XDCMX GD YNRW CM GIO MAR. C TRQ R
# _I____ _AS.
# QCKOUQ LRM.
#
# 	Key {'R': 'A', 'C': 'I', 'M': 'M', 'G': 'T', 'D': 'O'} ::
# 	Utility of 0.214 present in the puzzle
#
# ____'_ T__ T_IM_ A_O_T
# IOUO'Q GIO GICMX RADEG
# I_A_IMATIOM. IT _I___ _O_ AM
# CHRXCMRGCDM. CG XCPOQ WDE RM
# O__O_T_MIT_ TO ___A_, MO _ATT__,
# DYYDUGEMCGW GD VUORH, MD HRGGOU,
# _O_ _MO_, _O_ O_T_AM_I__ __
# WDE JMDT, IDT DEGNRMVCQI HW
# ___A__ ____. _I__, I T_O___T I _A_
# VUORHQ TOUO. NCJO, C GIDEXIG C TRQ
# _OIM_ TO __A_ IM T__ M_A. I _A_ A
# XDCMX GD YNRW CM GIO MAR. C TRQ R
# _I____ _AM.
# QCKOUQ LRM.
#
# 	Key {'R': 'A', 'C': 'I', 'M': 'N', 'G': 'T', 'H': 'O', 'W': 'F'} ::
# 	Utility of 0.214 present in the puzzle
#
# ____'_ T__ T_IN_ A___T
# IOUO'Q GIO GICMX RADEG
# IOA_INATI_N. IT _I___ F__ AN
# CHRXCMRGCDM. CG XCPOQ WDE RM
# _____T_NITF T_ ___AO, N_ OATT__,
# DYYDUGEMCGW GD VUORH, MD HRGGOU,
# F__ _N__, ___ __T_AN_I__ OF
# WDE JMDT, IDT DEGNRMVCQI HW
# ___AO_ ____. _I__, I T_____T I _A_
# VUORHQ TOUO. NCJO, C GIDEXIG C TRQ
# __IN_ T_ __AF IN T__ N_A. I _A_ A
# XDCMX GD YNRW CM GIO MAR. C TRQ R
# _I____ _AN.
# QCKOUQ LRM.
#
# 	Key {'R': 'A', 'C': 'I', 'M': 'N', 'G': 'T', 'H': 'O', 'W': 'F'} ::
# 	Utility of 0.214 present in the puzzle
#
# ____'_ T__ T_IN_ A___T
# IOUO'Q GIO GICMX RADEG
# IOA_INATI_N. IT _I___ F__ AN
# CHRXCMRGCDM. CG XCPOQ WDE RM
# _____T_NITF T_ ___AO, N_ OATT__,
# DYYDUGEMCGW GD VUORH, MD HRGGOU,
# F__ _N__, ___ __T_AN_I__ OF
# WDE JMDT, IDT DEGNRMVCQI HW
# ___AO_ ____. _I__, I T_____T I _A_
# VUORHQ TOUO. NCJO, C GIDEXIG C TRQ
# __IN_ T_ __AF IN T__ N_A. I _A_ A
# XDCMX GD YNRW CM GIO MAR. C TRQ R
# _I____ _AN.
# QCKOUQ LRM.
# Puzzle 1 -- Execution time for three letter words is 0:00:26.146470
# Puzzle 1 -- Maximum Utility is 0.38
# Puzzle 1  -- Node Count at 12
#
# 	Key {'R': 'A', 'C': 'I', 'M': 'S', 'G': 'T', 'H': 'O', 'W': 'F', 'I': 'H', 'O': 'E'} ::
# 	Utility of 0.354 present in the puzzle
#
# HE_E'_ THE THIS_ A___T
# IOUO'Q GIO GICMX RADEG
# IOA_ISATI_S. IT _I_E_ F__ AS
# CHRXCMRGCDM. CG XCPOQ WDE RM
# _____T_SITF T_ __EAO, S_ OATTE_,
# DYYDUGEMCGW GD VUORH, MD HRGGOU,
# F__ _S__, H__ __T_AS_I_H OF
# WDE JMDT, IDT DEGNRMVCQI HW
# __EAO_ _E_E. _I_E, I TH___HT I _A_
# VUORHQ TOUO. NCJO, C GIDEXIG C TRQ
# __IS_ T_ __AF IS THE S_A. I _A_ A
# XDCMX GD YNRW CM GIO MAR. C TRQ R
# _I_E__ _AS.
# QCKOUQ LRM.
#
# 	Key {'R': 'A', 'C': 'I', 'M': 'M', 'G': 'T', 'D': 'O', 'I': 'H', 'O': 'E'} ::
# 	Utility of 0.354 present in the puzzle
#
# HE_E'_ THE THIM_ A_O_T
# IOUO'Q GIO GICMX RADEG
# I_A_IMATIOM. IT _I_E_ _O_ AM
# CHRXCMRGCDM. CG XCPOQ WDE RM
# O__O_T_MIT_ TO __EA_, MO _ATTE_,
# DYYDUGEMCGW GD VUORH, MD HRGGOU,
# _O_ _MO_, HO_ O_T_AM_I_H __
# WDE JMDT, IDT DEGNRMVCQI HW
# __EA__ _E_E. _I_E, I THO__HT I _A_
# VUORHQ TOUO. NCJO, C GIDEXIG C TRQ
# _OIM_ TO __A_ IM THE M_A. I _A_ A
# XDCMX GD YNRW CM GIO MAR. C TRQ R
# _I_E__ _AM.
# QCKOUQ LRM.
#
# 	Key {'R': 'A', 'C': 'I', 'M': 'N', 'G': 'T', 'H': 'O', 'W': 'F', 'I': 'H', 'O': 'E'} ::
# 	Utility of 0.354 present in the puzzle
#
# HE_E'_ THE THIN_ A___T
# IOUO'Q GIO GICMX RADEG
# IOA_INATI_N. IT _I_E_ F__ AN
# CHRXCMRGCDM. CG XCPOQ WDE RM
# _____T_NITF T_ __EAO, N_ OATTE_,
# DYYDUGEMCGW GD VUORH, MD HRGGOU,
# F__ _N__, H__ __T_AN_I_H OF
# WDE JMDT, IDT DEGNRMVCQI HW
# __EAO_ _E_E. _I_E, I TH___HT I _A_
# VUORHQ TOUO. NCJO, C GIDEXIG C TRQ
# __IN_ T_ __AF IN THE N_A. I _A_ A
# XDCMX GD YNRW CM GIO MAR. C TRQ R
# _I_E__ _AN.
# QCKOUQ LRM.
#
# 	Key {'R': 'A', 'C': 'I', 'M': 'N', 'G': 'T', 'H': 'O', 'W': 'F', 'I': 'H', 'O': 'E'} ::
# 	Utility of 0.354 present in the puzzle
#
# HE_E'_ THE THIN_ A___T
# IOUO'Q GIO GICMX RADEG
# IOA_INATI_N. IT _I_E_ F__ AN
# CHRXCMRGCDM. CG XCPOQ WDE RM
# _____T_NITF T_ __EAO, N_ OATTE_,
# DYYDUGEMCGW GD VUORH, MD HRGGOU,
# F__ _N__, H__ __T_AN_I_H OF
# WDE JMDT, IDT DEGNRMVCQI HW
# __EAO_ _E_E. _I_E, I TH___HT I _A_
# VUORHQ TOUO. NCJO, C GIDEXIG C TRQ
# __IN_ T_ __AF IN THE N_A. I _A_ A
# XDCMX GD YNRW CM GIO MAR. C TRQ R
# _I_E__ _AN.
# QCKOUQ LRM.
